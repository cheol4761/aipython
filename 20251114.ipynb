# %%
import pandas as pd

student_data = {
    'name': ['Kim', 'Lee', 'Park'],
    'test': [85, 92, 78],
    'assign1': [88, 95, 80],
    'assign2': [91, 89, 82]
}
df = pd.DataFrame(student_data)
display(df)
# Out:
#    name  test  assign1  assign2
# 0   Kim    85       88       91
# 1   Lee    92       95       89
# 2  Park    78       80       82

# %%
data_list = [
 ['Kim', 85, 88, 91],
 ['Lee', 92, 95, 89],
 ['Park', 78, 80, 82]
 ]
column_names = ['name', 'test', 'assign1', 'assign2']


df_from_list = pd.DataFrame(data_list, columns=column_names)
display(df_from_list)
# Out:
#    name  test  assign1  assign2
# 0   Kim    85       88       91
# 1   Lee    92       95       89
# 2  Park    78       80       82

# %%
df_empty = pd.DataFrame()

df_empty['name'] = ['Kim', 'Lee', 'Park']
df_empty['test'] = [85, 92, 78]
df_empty['assign1'] = [88, 95, 80]
df_empty['assign2'] = [91, 89, 82]
display(df_empty)
# Out:
#    name  test  assign1  assign2
# 0   Kim    85       88       91
# 1   Lee    92       95       89
# 2  Park    78       80       82

# %%
import pandas as pd

df_iris = pd.read_csv('/content/Iris.csv')
display(df_iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### 1. `df.head(n)`: 데이터프레임의 상위 `n`개 행 보기

# %%
print("df_iris.head(5):")
display(df_iris.head(5))
# Out:
# df_iris.head(5):
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### 2. `df.tail(n)`: 데이터프레임의 하위 `n`개 행 보기

# %%
print("df_iris.tail(5):")
display(df_iris.tail(5))
# Out:
# df_iris.tail(5):
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ### 3. `df.info()`: 데이터프레임의 요약 정보 확인

# %%
print("df_iris.info():")
df_iris.info()
# Out:
# df_iris.info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ### 4. `df.describe()`: 수치형 데이터에 대한 기술 통계량

# %%
print("df_iris.describe():")
display(df_iris.describe())
# Out:
# df_iris.describe():
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### 5. `df.shape`: 데이터프레임의 행과 열 개수

# %%
print("df_iris.shape:", df_iris.shape)
# Out:
# df_iris.shape: (150, 6)

# %% [markdown]
# ### 6. `df.columns`: 열 이름 목록

# %%
print("df_iris.columns:", df_iris.columns)
# Out:
# df_iris.columns: Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ### 7. `df.index`: 인덱스 정보

# %%
print("df_iris.index:", df_iris.index)
# Out:
# df_iris.index: RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# ### 8. `df.dtypes`: 각 열의 데이터 타입

# %%
print("df_iris.dtypes:")
display(df_iris.dtypes)
# Out:
# df_iris.dtypes:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# ### 9. `df.isnull().sum()`: 각 열의 결측값 개수

# %%
print("df_iris.isnull().sum():")
display(df_iris.isnull().sum())
# Out:
# df_iris.isnull().sum():
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ### 10. `df['column'].value_counts()`: 특정 열의 고유 값 빈도

# %%
print("df_iris['Species'].value_counts():")
display(df_iris['Species'].value_counts())
# Out:
# df_iris['Species'].value_counts():
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### 11. `df.corr()`: 수치형 열 간의 상관 계수

# %%
print("df_iris.corr(numeric_only=True):")
display(df_iris.corr(numeric_only=True))
# Out:
# df_iris.corr(numeric_only=True):
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# ### 12. `df.groupby('column').mean()`: 특정 열 기준으로 그룹화 및 평균 계산

# %%
print("df_iris.groupby('Species').mean(numeric_only=True):")
display(df_iris.groupby('Species').mean(numeric_only=True))
# Out:
# df_iris.groupby('Species').mean(numeric_only=True):
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %% [markdown]
# ### 13. `df.drop_duplicates()`: 중복된 행 제거 (원본 데이터프레임은 변경하지 않음)

# %%
print("중복된 행 제거 후 df_iris의 shape (원본 변경 없음):", df_iris.drop_duplicates().shape)
print("원본 df_iris의 shape:", df_iris.shape)
# Out:
# 중복된 행 제거 후 df_iris의 shape (원본 변경 없음): (150, 6)
# 원본 df_iris의 shape: (150, 6)

# %%
df_iris_data = df_iris_data.

# %%
petal_dimensions = df_iris[['PetalLengthCm', 'PetalWidthCm']]

display(petal_dimensions.head())
# Out:
#    PetalLengthCm  PetalWidthCm
# 0            1.4           0.2
# 1            1.4           0.2
# 2            1.3           0.2
# 3            1.5           0.2
# 4            1.4           0.2

# %%
df_iris.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
print("df_iris.shape:", df_iris.shape)
# Out:
# df_iris.shape: (150, 6)

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# %%
font_path = ""
fontprop = font_manager.FontProperties(fname=font_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipython-input-622553441.py:1: SyntaxWarning: invalid escape sequence '\W'
#   font_path = "C:\Windows\Fonts\batang.ttc"

# %%
# 나눔 고딕 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (30.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 나눔 고딕 폰트 파일 경로 찾기
font_dirs = fm.findSystemFonts(fontpaths=None, fontext='ttf')
nanum_gothic_font = [f for f in font_dirs if 'NanumGothic' in f and 'Bold' not in f]

if nanum_gothic_font:
    font_path = nanum_gothic_font[0]
    fm.fontManager.addfont(font_path) # 폰트 매니저에 폰트 추가
    plt.rc('font', family=fm.FontProperties(fname=font_path).get_name())
    plt.rcParams['axes.unicode_minus'] = False

# %%
plt.title('기본 선형그래프')
plt.xlabel('X축 (시간)')
plt.ylabel('Y축 (값)')
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
#plt.grid(True)
plt.show()

# %%
fruits = ['사과', '바나나', '딸기']
counts = [10, 15, 7]
colors = ['green', 'yellow', 'red']

plt.bar(fruits, counts, color=colors)
plt.title('과일 판매량', fontsize=16)
plt.xlabel('과일 종류', fontsize=14)
plt.ylabel('판매 수량', fontsize=14)
# Out:
# Text(0, 0.5, '판매 수량')

# %%
import numpy as np
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.scatter(x, y)
plt.title('무작위 산점도')
plt.xlabel('X값')
plt.ylabel('Y값')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset('iris')
plt.figure(figsize=(10, 7))
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
plt.title('Iris 데이터셋의 산점도')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()

# %%
import pandas as pd

df_iris = pd.read_csv('/content/Iris.csv')
display(df_iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df_iris)
plt.title('Iris 데이터셋의 산점도')
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.show()
